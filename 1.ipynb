# %%
import MySQLdb as sql
import pandas as pd

db_connection = sql.connect(host='localhost', db='zhihu', user='root', passwd='123', charset = 'utf8')

df = pd.read_sql('SELECT distinct * FROM user', con=db_connection)

# %%
cur=db_connection.cursor() 
sql = "insert into final values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
cur.execute(sql,(df['id'][0],df['user_token'][0],df['location'][0],df['business'][0],df['sex'][0],
                    df['employment'][0],df['education'][0],df['username'][0],df['url'][0],df['agrees'][0],
                    df['thanks'][0],df['asks'][0],df['answers'][0],df['posts'][0],df['followees'][0],
                    df['followers'][0],df['topic1'][0],df['topic2'][0],df['topic3'][0],df['topic4'][0],
                    df['topic5'][0],df['hashId'][0]))
cur.close()
db_connection.commit()
db_connection.close()

# %%
df.to_csv('2017-7-24.csv',encoding = 'utf-8')

# %%
import MySQLdb as sql
import pandas as pd

db_connection = sql.connect(host='localhost', db='zhihu_user', user='root', passwd='123', charset = 'utf8')

df = pd.read_sql('SELECT * FROM t_user where username REGEXP "月明"', con=db_connection)

# %%
# coding=utf-8

from __future__ import unicode_literals, print_function

import os

from zhihu_oauth import ZhihuClient


TOKEN_FILE = 'token.pkl'


client = ZhihuClient()

if os.path.isfile(TOKEN_FILE):
    client.load_token(TOKEN_FILE)
else:
    client.login_in_terminal()
    client.save_token(TOKEN_FILE)
# Out:
# <zhihu_oauth.zhcls.generator.TopicGenerator object at 0x7f0a8db73dd0>

# %%
import MySQLdb as sql
import pandas as pd
from __future__ import unicode_literals, print_function

import os

from zhihu_oauth import ZhihuClient


TOKEN_FILE = 'token.pkl'


client = ZhihuClient()

if os.path.isfile(TOKEN_FILE):
    client.load_token(TOKEN_FILE)
else:
    client.login_in_terminal()
    client.save_token(TOKEN_FILE)



db_connection = sql.connect(host='localhost', db='zhihu', user='root', passwd='123', charset = 'utf8')
cur=db_connection.cursor() 
sql = "insert into final values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

df = pd.read_sql('SELECT distinct * FROM user', con=db_connection)



for i in range(100):
    url = 'http://www.zhihu.com/people/' + df['user_token'][i]
    print(i)
    author = client.from_url(url)
    topic = author.following_topics
    j = 0
    for t in topic:
        j = j + 1
        if(j == 1):
            df['topic1'][i] = t.name
        elif(j == 2):
            df['topic2'][i] = t.name
        elif(j == 3):
            df['topic3'][i] = t.name   
        elif(j == 4):
            df['topic4'][i] = t.name
        elif(j == 5):
            df['topic5'][i] = t.name
            break
    
    cur.execute(sql,(df['id'][i],df['user_token'][i],df['location'][i],df['business'][i],df['sex'][i],
                    df['employment'][i],df['education'][i],df['username'][i],df['url'][i],df['agrees'][i],
                    df['thanks'][i],df['asks'][0],df['answers'][i],df['posts'][i],df['followees'][i],
                    df['followers'][i],df['topic1'][i],df['topic2'][i],df['topic3'][i],df['topic4'][i],
                    df['topic5'][i],df['hashId'][i]))
    print(i + df['topic1'][i] )
    

cur.close()
db_connection.commit()
db_connection.close()

# %%
for i in range(10):
    url = 'http://www.zhihu.com/people/' + df['user_token'][i]
    print(i)
    author = client.from_url(url)
    topic = author.following_topics
    j = 0
    for t in topic:
        j = j + 1
        if(j == 1):
            df['topic1'][i] = t.name
        elif(j == 2):
            df['topic2'][i] = t.name
        elif(j == 3):
            df['topic3'][i] = t.name   
        elif(j == 4):
            df['topic4'][i] = t.name
        elif(j == 5):
            df['topic5'][i] = t.name
            df[i].to_sql(con=con, name='final', if_exists='append', flavor='mysql')
            break
# Out:
# 0
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-6af4ba5602a3> in <module>()
#      19         elif(j == 5):
#      20             df['topic5'][i] = t.name
# ---> 21             sql.write_frame(df, con=con, name='final', if_exists='append', flavor='mysql')
#      22             break
#      23
#
# AttributeError: 'module' object has no attribute 'write_frame'

# %%
df
# Out:
#             id                       user_token                     location  \
# 0            1                       wudongqing                           北京
# 1            2                           kapian                         None
# 2            3                       thomaskksj                         None
# 3            4                  shao-shu-pai-46                         None
# 4            5                           zoopda                           深圳
# 5            6                       sibyljiang                           北京
# 6            7             yixing-qi-xian-sheng                           南京
# 7            8                    gui-gu-mi-tan                         None
# 8            9                           a9x098  斯坦福大学 (Stanford University)
# 9           10                      mingkyle420                           杭州
# 10          11                         JudyZhao                           杭州
# 11          12                 xiang-yu-qing-86                         克拉玛依
# 12          13                     vipzhangxiao                           北京
# 13          14                      huang-yikai                         None
# 14          15              liang-qi-ying-xiang                           武汉
# 15          16                    wei-xin-yu-42                           香港
# 16          17                        fox4x4x4x                     ᐖᐇ  ᓏ  ᐛ
# 17          18                       daniel-hou                           美国
# 18          19                             yves                           深圳
# 19          20                    chenlong-shao                         深圳生活
# 20          21                  yang-peng-56-62                          石家庄
# 21          22                           faketo                           上海
# 22          23                      niu-peng-an                          石家庄
# 23          24                        gazhi-liu                          西朝鲜
# 24          25                       kenny_0922                          石家庄
# 25          26                  ding-shi-san-48                         None
# 26          27                        du-liu-70                         None
# 27          28                      wu-guan-jia                           武汉
# 28          29                      han-xue-wei                           老挝
# 29          30                       tang-bo-10                          深圳市
# ...        ...                              ...                          ...
# 676666  676667                    liu-xun-99-21                           西安
# 676667  676668              xie-yuan-yuan-29-94                         None
# 676668  676669          feng-xue-ye-gui-lang-66                         None
# 676669  676670                    ma-hong-yi-86                           上海
# 676670  676671                       qi-han-wei                          台北市
# 676671  676672     chang-jing-lu-xiao-jie-97-26                         None
# 676672  676673                  wang-jia-bin-12                         圣地亚哥
# 676673  676674    bu-feng-mo-bu-cheng-huo-59-18                         None
# 676674  676675                       wan-bao-la                         None
# 676675  676676                lin-fei-fei-25-99                         None
# 676676  676677                      zhe-ye-12-1                         None
# 676677  676678                  liu-han-qing-95                           北京
# 676678  676679                     chen-geng-68                         None
# 676679  676680                  lin-xi-26-15-20                           北京
# 676680  676681                         chqz1900                         None
# 676681  676682                       jiu-yin-26                         None
# 676682  676683                      yi-li-74-30                         None
# 676683  676684                     qing-zhou-79                         None
# 676684  676685                      soulcoaster                         None
# 676685  676686                     hua-hua-4-69                         None
# 676686  676687                         radio-xy                         None
# 676687  676688                          matt-24                         None
# 676688  676689                 chen-hao-yuan-49                         None
# 676689  676690                          fiochoi                         None
# 676690  676691                   lancetzhang-55                         None
# 676691  676692                  qing-ling-19-89                           上海
# 676692  676693                  kang-kang-97-91                         None
# 676693  676694                     po-hui-68-33                         None
# 676694  676695  xing-xiang-she-ji-shi-xiao-qing                         郑州大学
# 676695  676696                      ku-ma-xi-47                         None
#
#        business     sex                  employment  \
# 0           互联网    male                         蜂鸟网
# 1           互联网  female                         蜂鸟网
# 2            旅游    male                         摄影师
# 3          None    None                        None
# 4           互联网    male                        烧麦网络
# 5           互联网  female                 Airbnb（爱彼迎）
# 6           互联网    male                        None
# 7          None    None                        None
# 8            科研    male  斯坦福大学（Stanford University）
# 9           互联网    male                          网易
# 10         人力资源  female                        None
# 11         石油工业    male                      新疆油田公司
# 12          互联网    male                     北京大学出版社
# 13         None    male                        None
# 14         职业教育    male                  湖北传媒摄影技师学院
# 15         None    male                        None
# 16           保健    male                        None
# 17         地产建筑    male                Photographer
# 18          互联网    male                        None
# 19         None    male                        None
# 20           通信    male                        None
# 21           法律    male                        None
# 22         创意艺术    male                        蔓延视觉
# 23         None    male                     行星防御理事会
# 24         铁路运输    male                        None
# 25           渔业    male                        None
# 26         None    male                        None
# 27         None    male                        None
# 28          种植业    male                        None
# 29         电影录音    male                         街道办
# ...         ...     ...                         ...
# 676666     None    male                        None
# 676667     None    None                        None
# 676668       林业    male                        None
# 676669     None    male                        None
# 676670     创意艺术    male                        None
# 676671     None  female                        None
# 676672     市场推广    male                        None
# 676673     None    male                        None
# 676674     None  female                        None
# 676675     None    male                        None
# 676676     None    male                        None
# 676677       法律    male                        None
# 676678     电子游戏    male                        4399
# 676679     None  female                        None
# 676680     地产建筑  female                        None
# 676681     None  female                        None
# 676682     None    None                        None
# 676683     None    male                        None
# 676684     None    male                        None
# 676685     None  female                        None
# 676686     地产建筑    male                        None
# 676687     None    None                        None
# 676688     None    male                        None
# 676689     None    None                        None
# 676690       科研    male                        None
# 676691       政府  female                        None
# 676692     None  female                        None
# 676693      服装业  female                        None
# 676694     创意艺术  female                        None
# 676695     None    None                        None
#
#                                        education     username   url  agrees  \
# 0                                           None          武冬青  None   10852
# 1                                           None           卡片  None    6016
# 2       南洋理工大学（Nanyang Technological University）   Thomas看看世界  None   33241
# 3                                           None          少数派  None    8686
# 4                                       黑龙江中医药大学           老麦  None    1178
# 5                                           北京大学          小酱桶  None    4259
# 6                                           None        一星期先生  None   23277
# 7                                           None         硅谷密探  None   27479
# 8                    斯坦福大学 (Stanford University)          陈志谦  None       0
# 9                                           None          赵明亿  None   11151
# 10                                        香港中文大学      别叫我Judy  None   21614
# 11                                    中国石油大学（北京）          翔宇情  None   71236
# 12                                        长沙理工大学          张二二  None   37544
# 13                                          None          黄一凯  None   32849
# 14                                        广州美术学院         惊奇影像  None   39677
# 15                                 香港中文大学 (CUHK)          魏鑫宇  None   25938
# 16                                          None          野合菌  None  273575
# 17                                          None          侯不才  None    1025
# 18                                          None         Yves  None      77
# 19                                          None       chen龙少  None      54
# 20                                          None           杨芃  None    4141
# 21                                      上海对外经贸大学         POTM  None    2011
# 22                                          河北大学          牛鹏安  None     812
# 23                                          None     liugazhi  None    6455
# 24                                          None           陈坦  None   15517
# 25                                          None           陆离  None    2574
# 26                                          None           毒瘤  None    9090
# 27                                        华中科技大学          文亚真  None    6979
# 28                                          None          韩学伟  None    2207
# 29                                          None          唐三皮  None    2798
# ...                                          ...          ...   ...     ...
# 676666                                      None           刘巡  None     874
# 676667                                      None          谢元元  None       0
# 676668                                     克莱登大学        风雪夜归狼  None       1
# 676669                                      None           扶风  None    2986
# 676670                                      None         果凍效益  None       7
# 676671                                      None           何寻  None      36
# 676672                   加州大学圣迭戈分校（UC-San Diego）           不息  None       2
# 676673                                      None       不疯魔不成活  None      10
# 676674                                      None          万宝拉  None       0
# 676675                                      None           倒影  None       3
# 676676                                      None           者也  None      23
# 676677                           对外经济贸易大学 (UIBE)         解忧杂货  None      28
# 676678                                      None         喊地神牛  None      24
# 676679                                      None           百目  None       0
# 676680                                      None         沧海轻舟  None       0
# 676681                                      None           久因  None       0
# 676682                                      None           汉隶  None       0
# 676683                                      None           青舟  None     276
# 676684                                      None         水底的猫  None       0
# 676685                                      None         不猛不行  None      71
# 676686                                      None     radio xy  None       6
# 676687                                      None         Gift  None       2
# 676688                                      None          陈好远  None      65
# 676689                                      None          蔡瑞标  None      77
# 676690                                      None  lancetzhang  None     457
# 676691                                      None           青皊  None       0
# 676692                                      None           康康  None       0
# 676693                                      None           朴惠  None       0
# 676694                                      None      形象设计师林子  None     159
# 676695                                      None          库马西  None       8
#
#                       ...                 answers  posts  followees  \
# 0                     ...                     223     57        148
# 1                     ...                      10      0        381
# 2                     ...                      25     48        110
# 3                     ...                      28    112         18
# 4                     ...                      48      1        264
# 5                     ...                      16      0        169
# 6                     ...                      26     10        207
# 7                     ...                     117     79         93
# 8                     ...                       2      2          2
# 9                     ...                       5    124        174
# 10                    ...                      25     37         65
# 11                    ...                    2321     56        489
# 12                    ...                     109     11        113
# 13                    ...                     141     15        567
# 14                    ...                     651     33        172
# 15                    ...                     131     24        294
# 16                    ...                    3956      9          1
# 17                    ...                      65      0         91
# 18                    ...                      11      5        192
# 19                    ...                      66      0         17
# 20                    ...                     151      0        255
# 21                    ...                      56      0        127
# 22                    ...                      39      0        159
# 23                    ...                      55      0       5000
# 24                    ...                     190      0        330
# 25                    ...                      89      0         98
# 26                    ...                      16      0        272
# 27                    ...                      32      0        223
# 28                    ...                      47      0       1231
# 29                    ...                     146      0        229
# ...                   ...                     ...    ...        ...
# 676666                ...                     197      0         40
# 676667                ...                       0      0          1
# 676668                ...                       3      0          5
# 676669                ...                      18      1         10
# 676670                ...                       3      1          3
# 676671                ...                      33      0          5
# 676672                ...                      12      0         56
# 676673                ...                      16      0         95
# 676674                ...                       2      0         51
# 676675                ...                       9      0        545
# 676676                ...                       1      0        267
# 676677                ...                      22      0        200
# 676678                ...                      36      0        123
# 676679                ...                       3      0        435
# 676680                ...                       0      0         31
# 676681                ...                       0      0          2
# 676682                ...                       0      0          3
# 676683                ...                      22      0        324
# 676684                ...                       2      0        236
# 676685                ...                      53      0        291
# 676686                ...                       8      0        326
# 676687                ...                       3      0        494
# 676688                ...                      70      1         44
# 676689                ...                       3      0          2
# 676690                ...                      28      0        169
# 676691                ...                       0      0          3
# 676692                ...                       0      0          1
# 676693                ...                       0      0          0
# 676694                ...                      12      2          3
# 676695                ...                       1      0          5
#
#         followers  topic1           topic2              topic3  \
# 0            8406      摄影             摄影技巧                摄影技术
# 1            2592      生活               恋爱                生活方式
# 2           28284      摄影             摄影技巧              摄影后期技术
# 3            8662  WWDC17         Markdown                  摄影
# 4            1572     互联网         iOS 应用推荐           App Store
# 5            4807      摄影      Airbnb（爱彼迎）                  艺术
# 6           12603      摄影             手机摄影                人际交往
# 7           26031     互联网               创业                  科技
# 8              14      投资               摄影                  文化
# 9            5233  iOS 应用        iPhone 应用            iOS 应用推荐
# 10          29964      摄影               旅行                  时尚
# 11          34583      摄影             单反相机                摄影器材
# 12          37762      摄影             摄影技巧                人像摄影
# 13          23853      摄影               语义      AlphaGo（阿尔法围棋）
# 14          27743      摄影             摄影技巧                 摄影师
# 15           7408      摄影              NBA                  数学
# 16          83930      医学               生活                  科学
# 17            231    土木工程  Adobe Photoshop  魔兽争霸 3（Warcraft 3）
# 18            197    用户体验               知乎              iPhone
# 19             30      摄影              威锋网                  游戏
# 20            228      摄影               结婚                  耳机
# 21            140      法律            守望先锋‭          漫威（Marvel）
# 22            122      摄影             摄影技术                摄影器材
# 23            693      摄影               美剧                  电影
# 24            713      铁路            调查类问题                轨道列车
# 25            308      摄影               艺术                 心理学
# 26            197      律师               设计                  电影
# 27            941    城市规划               历史                  设计
# 28            165      生活              淘宝网                  摄影
# 29            368      摄影               电影                  爱情
# ...           ...     ...              ...                 ...
# 676666         42    None             None                None
# 676667          1    None             None                None
# 676668          2    None             None                None
# 676669        157    None             None                None
# 676670          5    None             None                None
# 676671          4    None             None                None
# 676672          6    None             None                None
# 676673          1    None             None                None
# 676674          3    None             None                None
# 676675          2    None             None                None
# 676676          6    None             None                None
# 676677         14    None             None                None
# 676678          6    None             None                None
# 676679         16    None             None                None
# 676680          2    None             None                None
# 676681          1    None             None                None
# 676682          1    None             None                None
# 676683         13    None             None                None
# 676684          4    None             None                None
# 676685         10    None             None                None
# 676686          8    None             None                None
# 676687          6    None             None                None
# 676688         50    None             None                None
# 676689         22    None             None                None
# 676690         27    None             None                None
# 676691          1    None             None                None
# 676692          3    None             None                None
# 676693          1    None             None                None
# 676694         98    None             None                None
# 676695          4    None             None                None
#
#                    topic4           topic5                            hashId
# 0                    单反相机               照片  809b47e0d0e09fca57a195a9eb88d5a4
# 1                      摄影              心理学  0cac61291dc0e894f056f7a06b2ab2d8
# 2                    摄影器材  Adobe Photoshop  d8c71392487aa83d654e6aa36c4e5dce
# 3                    None             None  e3c85e95321538c49d13852df5abdb01
# 4                  消费电子产品             高效工作  b00c41afc89ff96b0b0e5c6a92fe2716
# 5                     摄影师               美食  bfdfdd37626d10bfeec0c458c4fbbbb0
# 6                  摄影后期技术               旅行  166ff125029881c4cf210ad90b8cf963
# 7                      硅谷              黑科技  52e5d162ad14a515e65140b61f282fba
# 8                    None             None  b3231a6a33661726ac5bfeaa69cfe71c
# 9                     互联网         2016 年盘点  0b7f860313a692810e8f950d8e426561
# 10                   摄影技巧               美食  2a3ef9acf030f61aaa93150032d1b9a4
# 11                     相机             摄影技术  71de14d92f495b802031574ff2436456
# 12                 摄影后期技术             摄影器材  cb0e0dde840f96a378f4b054a57a2ef1
# 13                   罗曼语族             印欧语系  7cc6fd849698a70bbe086baa6d8356bd
# 14                   单反相机             摄影器材  61ad5a0e50d420e70efd283d0cae9a24
# 15          香港中文大学 (CUHK)               香港  019d91bf4ae8c40ac24dc091f2fc9c7a
# 16                     科技             生活常识  e86236d75737694119d266f18c4c1794
# 17                 摄影后期技术          表（计时工具）  32cdda427c4bcde581a45cce5676bda1
# 18          Google Chrome      谷歌 (Google)  676421b7c58a6de060215820466d819d
# 19                     商业           酒店管理专业  37fe54bfaad108611b1ee32d8a23f54f
# 20                    物理学               光学  eb9eda5975d488a09843a7c266c31c2e
# 21                     刑法               摄影  3998ab678532564467a14289dd1a3f86
# 22                   摄影技巧           摄影后期技术  2bdf718787d68c168117a5a897dfeca8
# 23                     历史        权力的游戏（美剧）  6b66c1192db1c07b468c553d5c2c3e51
# 24                     电影               高铁  ad2bd4160ec7b960ce2d2ee701f8396c
# 25                   日本文化               音乐  0c8917b0d2dff1ab15e1356e515a1d4d
# 26                     游戏               创意  b533ffa8ed5cb59cbd09dc829ce29c45
# 27                     城市               人文  bc59515f796f62f2046b1f3944949a33
# 28              X 是种怎样的体验               阅读  46a3900a0392271dd14a83dd11c377fd
# 29      苹果公司 (Apple Inc.)              Mac  fa2d6de312569e6a41583d7cd375c06a
# ...                   ...              ...                               ...
# 676666               None             None  9dd09c5063318adc7147ad2061fb841e
# 676667               None             None  6682278d1f737bc2ae76d3c9ce842c88
# 676668               None             None  18a435bc34363f44030f06349e293b1d
# 676669               None             None  3a54f2c07fd390323ea180567ac34ee1
# 676670               None             None  8d53bfd2134a95b4f6149872426f2b89
# 676671               None             None  31f5a1d9ef6486322b7011b1af354b66
# 676672               None             None  ac2c64cbb019e02ff6f5fe4acf839b6a
# 676673               None             None  e4aa24ee6e41790d374e6f7760846786
# 676674               None             None  30bcb856aeae789b475532b6e21e92d1
# 676675               None             None  7e56f9454332d4462cf0b65c2f5a3c62
# 676676               None             None  07b2f599f4f413292609eaa64c30dd04
# 676677               None             None  867a1d69400b57fe61889f1a9b4ebf89
# 676678               None             None  aa04030a62d2d9c634d5b03316d24e3f
# 676679               None             None  d341a11309e79df6d0f8981793fa2e39
# 676680               None             None  c2a9c6bb4979b37875ec5d3e3bbc1a33
# 676681               None             None  fd44148e4c41cedf9832be6034db4954
# 676682               None             None  9e7364476b991f8d6c0d3e154ddce5a9
# 676683               None             None  c7b09c0b0fb5a3b944035bfd65fe63d4
# 676684               None             None  5c34bf80c653c0ea2cc12a4e53d65d92
# 676685               None             None  aecc6f823b74ab497830ae9f30756041
# 676686               None             None  714d58ce79a0014955d87cf738da29a3
# 676687               None             None  e8a27cbfd41c2d70bd2146bb12f33118
# 676688               None             None  93d8fe8645e325b1aff652cc4aa8f36d
# 676689               None             None  827c2e93a91358c2e16436b94adc6ea6
# 676690               None             None  6d8c58d05c5bba0b1a0163706cc93a82
# 676691               None             None  560ba11736d1ee8871e096225b3293b6
# 676692               None             None  12ff88a37abb0df015ce26dccd767983
# 676693               None             None  9511ed1a8042c26b01536789cb79ab36
# 676694               None             None  df7a2291f796b3b97ae9111ff794f637
# 676695               None             None  21e8d530228ab2e717fbfb9559bfceca
#
# [676696 rows x 22 columns]

# %%
print(topic[0].name)
print(topic[1].name)
print(topic[2].name)
print(topic[3].name)
print(topic[4].name)
# Out:
# 理光 (Ricoh)
# 软装设计
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-68d1a5005aa5> in <module>()
#       1 print(topic[0].name)
#       2 print(topic[1].name)
# ----> 3 print(topic[2].name)
#       4 print(topic[3].name)
#       5 print(topic[4].name)
#
# /usr/local/lib/python2.7/dist-packages/zhihu_oauth/zhcls/generator.pyc in __getitem__(self, item)
#     161                 self._fetch_more()
#     162             else:
# --> 163                 raise IndexError('list index out of range')
#     164         return self._build_obj(self._data[item])
#     165
#
# IndexError: list index out of range

# %%
topic.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-acaa0b2079de> in <module>()
# ----> 1 topic.size
#
# AttributeError: 'TopicGenerator' object has no attribute 'size'
